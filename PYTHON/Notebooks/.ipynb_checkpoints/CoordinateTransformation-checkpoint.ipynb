# %% [markdown]
# Coordinate Transformation with pyproj
# =====================
#
# This note book reads in an XYZ data file and converts the coordinate system using the pyproj library
#
# Requirements
# --------------
#
# pip install pyproj
#
#
#
# Written by: Dom F.
# Created: May 4th, 2018

# %%
import pyproj
import numpy as np
# %pylab inline

workDir = ".\\"
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Read in the xyz_data file in column format
xydata = np.loadtxt(workDir + "country-capitals.csv", delimiter=",")

# Flip lat-lon to lon-lat
xydata = xydata[:,::-1]

# Plot it
plt.figure()
plt.scatter(xydata[:,0],xydata[:,1])
plt.title('Capitals of the world - WGS84')
plt.gca().set_aspect('equal')
plt.gca().set_xlim([-200, 200])
# Out:
# (-200, 200)

# %%
# Specify the coordinate systems
systemIn = pyproj.Proj("+init=EPSG:4326") # Code for WGS84 Lat-Lon
systemOut = pyproj.Proj("+init=EPSG:26907") # UTM NAD83 zone 7N

# Convert the x,y locations
xOut, yOut = pyproj.transform(systemIn, systemOut, xydata[:,0], xydata[:,1])

# Swap the x,y coordinates
xyDataOut = np.c_[xOut, yOut, xydata[:,2:]]

# Export to a new file
np.savetxt(workDir + "datafileOut.xyz", xyDataOut, fmt='%.8e', delimiter='\t')

# %%
# Plot new coord
plt.figure()
plt.scatter(xyDataOut[:,0], xyDataOut[:,1])
plt.title('Capitals of the world - UTM NAD83 zone 7N')
# Out:
# Text(0.5, 1.0, 'Capitals of the world - UTM NAD83 zone 7N')

# %% [markdown]
# # User defined transformation

# %%
# Rotation matrix
def Rz(theta):
    """Rotation matrix about z axis"""
    Rz = np.vstack(
        (np.r_[np.cos((theta)), -np.sin((theta))],
         np.r_[np.sin((theta)), np.cos((theta))])
    )
    
    return Rz

# Define center of rotation
center = np.kron(np.ones((xydata.shape[0], 1)), np.c_[50, 50])

# Define rotation angle  (positive counter-clockwise)
angle = np.deg2rad(30)

# Perform transformation
xydataRot = np.dot(Rz(angle), xydata.T - center.T).T + center

# %%
plt.figure()
plt.scatter(xydataRot[:,0], xydataRot[:,1])
plt.scatter(center[0,0], center[0,1], 15, 'r')
plt.title('Capitals of the world - Rotated:' + str(np.rad2deg(angle)) + " from: " + str(center[0,:])) 
plt.gca().set_aspect('equal')
plt.gca().set_xlim([-200, 200])
# Out:
# (-200, 200)
